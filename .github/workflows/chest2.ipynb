# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=10, class_weight=dict(enumerate(class_weights)))

data_test = keras.preprocessing.image.ImageDataGenerator(

).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 164/164 [==============================] - 709s 4s/step - loss: 0.6166 - accuracy: 0.7354
# Epoch 2/10
# 164/164 [==============================] - 163s 992ms/step - loss: 0.6173 - accuracy: 0.7417
# Epoch 3/10
# 164/164 [==============================] - 165s 1s/step - loss: 0.6180 - accuracy: 0.7412
# Epoch 4/10
# 164/164 [==============================] - 163s 997ms/step - loss: 0.6174 - accuracy: 0.7412
# Epoch 5/10
# 164/164 [==============================] - 162s 987ms/step - loss: 0.6178 - accuracy: 0.7412
# Epoch 6/10
# 164/164 [==============================] - 162s 990ms/step - loss: 0.6176 - accuracy: 0.7412
# Epoch 7/10
# 164/164 [==============================] - 163s 994ms/step - loss: 0.6175 - accuracy: 0.7412
# Epoch 8/10
# 164/164 [==============================] - 163s 997ms/step - loss: 0.6183 - accuracy: 0.7412
# Epoch 9/10
# 164/164 [==============================] - 163s 993ms/step - loss: 0.6177 - accuracy: 0.7412
# Epoch 10/10
# 164/164 [==============================] - 163s 992ms/step - loss: 0.6174 - accuracy: 0.7412
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 155s 8s/step - loss: 0.6636 - accuracy: 0.6250
# [0.6635653972625732, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.02, nesterov=True, momentum=0.95),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=10)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 532, 399, 8)       208
#
#  conv2d_6 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_1 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_7 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_8 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 192)               0
#
#  dense_2 (Dense)             (None, 32)                6176
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 164/164 [==============================] - 173s 1s/step - loss: 0.5747 - accuracy: 0.7375
# Epoch 2/10
# 164/164 [==============================] - 165s 1s/step - loss: 0.5730 - accuracy: 0.7412
# Epoch 3/10
# 164/164 [==============================] - 164s 998ms/step - loss: 0.5731 - accuracy: 0.7412
# Epoch 4/10
# 164/164 [==============================] - 163s 993ms/step - loss: 0.5743 - accuracy: 0.7412
# Epoch 5/10
# 164/164 [==============================] - 162s 989ms/step - loss: 0.5737 - accuracy: 0.7412
# Epoch 6/10
# 164/164 [==============================] - 163s 995ms/step - loss: 0.5734 - accuracy: 0.7412
# Epoch 7/10
# 164/164 [==============================] - 165s 1s/step - loss: 0.5722 - accuracy: 0.7412
# Epoch 8/10
# 164/164 [==============================] - 163s 992ms/step - loss: 0.5729 - accuracy: 0.7412
# Epoch 9/10
# 164/164 [==============================] - 163s 991ms/step - loss: 0.5730 - accuracy: 0.7412
# Epoch 10/10
# 164/164 [==============================] - 166s 1s/step - loss: 0.5725 - accuracy: 0.7412
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 18s 916ms/step - loss: 0.6945 - accuracy: 0.6250
# [0.6944915056228638, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=1, class_weight=dict(enumerate(class_weights)))

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# 164/164 [==============================] - 170s 987ms/step - loss: 0.6113 - accuracy: 0.7454
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 18s 904ms/step - loss: 0.6639 - accuracy: 0.6250
# [0.6639419198036194, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=2, class_weight=dict(enumerate(class_weights)))

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 164/164 [==============================] - 174s 1s/step - loss: 0.6218 - accuracy: 0.7337
# Epoch 2/2
# 164/164 [==============================] - 163s 997ms/step - loss: 0.6179 - accuracy: 0.7412
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 925ms/step - loss: 0.6621 - accuracy: 0.6250
# [0.662096381187439, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x: x / 255,
    rotation_range=20,  # Random rotation in the range of [-20, 20] degrees
    width_shift_range=0.2,  # Random horizontal shift by 20% of the image width
    height_shift_range=0.2,  # Random vertical shift by 20% of the image height
    shear_range=0.2,  # Shear transformation with a range of 0.2
    zoom_range=0.2,  # Random zoom in/out by 20%
    horizontal_flip=True  # 
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=1)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 532, 399, 8)       208
#
#  conv2d_6 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_1 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_7 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_8 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 192)               0
#
#  dense_2 (Dense)             (None, 32)                6176
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# 164/164 [==============================] - 805s 5s/step - loss: 0.5781 - accuracy: 0.7398
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 919ms/step - loss: 0.6878 - accuracy: 0.6250
# [0.6878265738487244, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
class_weights = np.array([0.8, 1.3333])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=4, class_weight=dict(enumerate(class_weights)))

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
# 164/164 [==============================] - 1195s 7s/step - loss: 0.5459 - accuracy: 0.7431
# Epoch 2/4
# 164/164 [==============================] - 1126s 7s/step - loss: 0.5519 - accuracy: 0.7412
# Epoch 3/4
# 164/164 [==============================] - 1130s 7s/step - loss: 0.5517 - accuracy: 0.7412
# Epoch 4/4
# 164/164 [==============================] - 1161s 7s/step - loss: 0.5519 - accuracy: 0.7412
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 80s 4s/step - loss: 0.7944 - accuracy: 0.6250
# [0.79444819688797, 0.625]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
#from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=4)

data_test = keras.preprocessing.image.ImageDataGenerator(
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,458
# Trainable params: 57,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
# 164/164 [==============================] - 498s 3s/step - loss: nan - accuracy: 0.2634
# Epoch 2/4
# 164/164 [==============================] - 162s 986ms/step - loss: nan - accuracy: 0.2588
# Epoch 3/4
# 164/164 [==============================] - 162s 988ms/step - loss: nan - accuracy: 0.2588
# Epoch 4/4
# 164/164 [==============================] - 162s 990ms/step - loss: nan - accuracy: 0.2588
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 100s 5s/step - loss: nan - accuracy: 0.3750
# [nan, 0.375]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=3)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 532, 399, 8)       208
#
#  batch_normalization_5 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_26 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_5 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_27 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_28 (Conv2D)          (None, 42, 31, 16)        6288
#
#  max_pooling2d_10 (MaxPoolin  (None, 21, 15, 16)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 7, 4, 32)          41504
#
#  max_pooling2d_11 (MaxPoolin  (None, 3, 2, 32)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 192)               0
#
#  dense_10 (Dense)            (None, 32)                6176
#
#  dense_11 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 180s 1s/step - loss: 0.3701 - accuracy: 0.8641
# Epoch 2/3
# 164/164 [==============================] - 171s 1s/step - loss: 0.1670 - accuracy: 0.9412
# Epoch 3/3
# 164/164 [==============================] - 173s 1s/step - loss: 0.1313 - accuracy: 0.9529
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 926ms/step - loss: 0.5796 - accuracy: 0.7340
# [0.5795853137969971, 0.7339743375778198]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=1)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 532, 399, 8)       208
#
#  batch_normalization_2 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_2 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_12 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_13 (Conv2D)          (None, 42, 31, 16)        6288
#
#  max_pooling2d_4 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 7, 4, 32)          41504
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 192)               0
#
#  dense_4 (Dense)             (None, 32)                6176
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# 164/164 [==============================] - 173s 1s/step - loss: 0.4038 - accuracy: 0.8255
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 932ms/step - loss: 0.5526 - accuracy: 0.6538
# [0.5526397824287415, 0.6538461446762085]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=2)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 532, 399, 8)       208
#
#  batch_normalization_3 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_3 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_17 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_18 (Conv2D)          (None, 42, 31, 16)        6288
#
#  max_pooling2d_6 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 7, 4, 32)          41504
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 192)               0
#
#  dense_6 (Dense)             (None, 32)                6176
#
#  dense_7 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/2
# 164/164 [==============================] - 175s 1s/step - loss: 0.4962 - accuracy: 0.7675
# Epoch 2/2
# 164/164 [==============================] - 171s 1s/step - loss: 0.2645 - accuracy: 0.8889
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 921ms/step - loss: 0.9214 - accuracy: 0.6795
# [0.9213619828224182, 0.6794871687889099]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=4)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 532, 399, 8)       208
#
#  batch_normalization_6 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_31 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_6 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_32 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_33 (Conv2D)          (None, 42, 31, 16)        6288
#
#  max_pooling2d_12 (MaxPoolin  (None, 21, 15, 16)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 7, 4, 32)          41504
#
#  max_pooling2d_13 (MaxPoolin  (None, 3, 2, 32)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 192)               0
#
#  dense_12 (Dense)            (None, 32)                6176
#
#  dense_13 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/4
# 164/164 [==============================] - 174s 1s/step - loss: 0.3375 - accuracy: 0.8538
# Epoch 2/4
# 164/164 [==============================] - 171s 1s/step - loss: 0.1312 - accuracy: 0.9523
# Epoch 3/4
# 164/164 [==============================] - 170s 1s/step - loss: 0.1406 - accuracy: 0.9452
# Epoch 4/4
# 164/164 [==============================] - 174s 1s/step - loss: 0.0928 - accuracy: 0.9641
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 942ms/step - loss: 0.7284 - accuracy: 0.7804
# [0.7283616065979004, 0.7804487347602844]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.8),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=6)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  batch_normalization (BatchN  (None, 532, 399, 8)      32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout (Dropout)           (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/6
# 164/164 [==============================] - 754s 4s/step - loss: 0.2759 - accuracy: 0.8885
# Epoch 2/6
# 164/164 [==============================] - 176s 1s/step - loss: 0.1289 - accuracy: 0.9530
# Epoch 3/6
# 164/164 [==============================] - 179s 1s/step - loss: 0.1039 - accuracy: 0.9597
# Epoch 4/6
# 164/164 [==============================] - 181s 1s/step - loss: 0.0833 - accuracy: 0.9683
# Epoch 5/6
# 164/164 [==============================] - 178s 1s/step - loss: 0.0764 - accuracy: 0.9729
# Epoch 6/6
# 164/164 [==============================] - 178s 1s/step - loss: 0.0637 - accuracy: 0.9742
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 116s 6s/step - loss: 1.0082 - accuracy: 0.7420
# [1.008197546005249, 0.7419871687889099]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
#class_weights = np.array([1.3333, 0.8])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (9, 9), strides=(2, 2), activation='relu'),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.8),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=4)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 532, 399, 8)       208
#
#  batch_normalization_1 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_1 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_7 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_8 (Conv2D)           (None, 42, 31, 16)        6288
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 4, 32)          41504
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 192)               0
#
#  dense_2 (Dense)             (None, 32)                6176
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 57,490
# Trainable params: 57,474
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/4
# 164/164 [==============================] - 183s 1s/step - loss: 0.2740 - accuracy: 0.8838
# Epoch 2/4
#  32/164 [====>.........................] - ETA: 2:23 - loss: 0.1598 - accuracy: 0.9482

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight

data = keras.preprocessing.image.ImageDataGenerator(
preprocessing_function=lambda x:x/255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)


# Calculate class weights
class_weights = np.array([1, 1])

model = keras.Sequential([
    keras.layers.Input((1600, 1200, 1)),
    keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Conv2D(32, (5, 5), strides=(2, 2), activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.MaxPool2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(2, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01, nesterov=True, momentum=0.90),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

history = model.fit(data, verbose=1, epochs=4)

data_test = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x: x / 255
).flow_from_directory(
    "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
    target_size=(1600, 1200),
    color_mode='grayscale',
    classes=None,
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

model.evaluate(data_test)
# Out:
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  dropout (Dropout)           (None, 532, 399, 8)       0
#
#  batch_normalization (BatchN  (None, 532, 399, 8)      32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_1 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  dropout_2 (Dropout)         (None, 42, 31, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 9, 6, 32)          12832
#
#  dropout_3 (Dropout)         (None, 9, 6, 32)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 384)               0
#
#  dense (Dense)               (None, 32)                12320
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/4
# 164/164 [==============================] - 795s 4s/step - loss: 0.5589 - accuracy: 0.7526
# Epoch 2/4
# 164/164 [==============================] - 168s 1s/step - loss: 0.3439 - accuracy: 0.8471
# Epoch 3/4
# 164/164 [==============================] - 172s 1s/step - loss: 0.1546 - accuracy: 0.9435
# Epoch 4/4
# 164/164 [==============================] - 172s 1s/step - loss: 0.1307 - accuracy: 0.9529
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 177s 9s/step - loss: 0.7567 - accuracy: 0.6667
# [0.756677508354187, 0.6666666865348816]

# %%
import tensorflow as tf
from tensorflow import keras
#from imblearn.over_sampling import RandomOverSampler
import numpy as np
from sklearn.utils import class_weight


lr_array = np.array([0.011, 0.013])
momentum_array = np.array([0.9, 0.92, 0.94])

for lr in lr_array:
  for momentum_var in momentum_array:
    print("*"*20)
    print("*"*20)
    print("learning rate",lr)
    print("momentum", momentum_var)
    

    data = keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=lambda x:x/255
    ).flow_from_directory(
        "/content/gdrive/MyDrive/chest/datai2/chest_xray/train",
        target_size=(1600, 1200),
        color_mode='grayscale',
        classes=None,
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=None,
        save_to_dir=None,
        save_prefix='',
        save_format='png',
        follow_links=False,
        subset=None,
        interpolation='nearest',
        keep_aspect_ratio=False
    )


    # Calculate class weights
    class_weights = np.array([1, 1])

    model = keras.Sequential([
        keras.layers.Input((1600, 1200, 1)),
        keras.layers.Conv2D(8, (5, 5), strides=(3, 3), activation='relu'),
        keras.layers.Dropout(0.1),
        keras.layers.BatchNormalization(),
        keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Conv2D(8, (5, 5), strides=(2, 2), activation='relu'),
        keras.layers.Conv2D(16, (7, 7), strides=(3, 3), activation='relu'),
        keras.layers.Dropout(0.1),
        keras.layers.MaxPool2D((2, 2)),
        keras.layers.Conv2D(32, (5, 5), strides=(2, 2), activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.MaxPool2D((2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dense(2, activation="softmax"),
    ])

    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=lr, nesterov=True, momentum=momentum_var),
        loss=tf.keras.losses.CategoricalCrossentropy(),
        metrics=["accuracy"]
    )

    model.summary()

    history = model.fit(data, verbose=1, epochs=3)

    data_test = keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=lambda x: x / 255
    ).flow_from_directory(
        "/content/gdrive/MyDrive/chest/datai2/chest_xray/test",
        target_size=(1600, 1200),
        color_mode='grayscale',
        classes=None,
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=None,
        save_to_dir=None,
        save_prefix='',
        save_format='png',
        follow_links=False,
        subset=None,
        interpolation='nearest',
        keep_aspect_ratio=False
    )

    model.evaluate(data_test)
# Out:
# ********************
# ********************
# learning rate 0.011
# momentum 0.9
# Found 5239 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 532, 399, 8)       208
#
#  dropout (Dropout)           (None, 532, 399, 8)       0
#
#  batch_normalization (BatchN  (None, 532, 399, 8)      32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_1 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_2 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_3 (Conv2D)           (None, 42, 31, 16)        6288
#
#  dropout_2 (Dropout)         (None, 42, 31, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 21, 15, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 9, 6, 32)          12832
#
#  dropout_3 (Dropout)         (None, 9, 6, 32)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 384)               0
#
#  dense (Dense)               (None, 32)                12320
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 541s 3s/step - loss: 0.4184 - accuracy: 0.8074
# Epoch 2/3
# 164/164 [==============================] - 166s 1s/step - loss: 0.1627 - accuracy: 0.9372
# Epoch 3/3
# 164/164 [==============================] - 167s 1s/step - loss: 0.1484 - accuracy: 0.9477
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 112s 6s/step - loss: 0.4135 - accuracy: 0.8109
# ********************
# ********************
# learning rate 0.011
# momentum 0.92
# Found 5239 images belonging to 2 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 532, 399, 8)       208
#
#  dropout_4 (Dropout)         (None, 532, 399, 8)       0
#
#  batch_normalization_1 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 264, 198, 8)       1608
#
#  dropout_5 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_7 (Conv2D)           (None, 130, 97, 8)        1608
#
#  conv2d_8 (Conv2D)           (None, 42, 31, 16)        6288
#
#  dropout_6 (Dropout)         (None, 42, 31, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 9, 6, 32)          12832
#
#  dropout_7 (Dropout)         (None, 9, 6, 32)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 384)               0
#
#  dense_2 (Dense)             (None, 32)                12320
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 170s 1s/step - loss: 0.4791 - accuracy: 0.7881
# Epoch 2/3
# 164/164 [==============================] - 167s 1s/step - loss: 0.1720 - accuracy: 0.9370
# Epoch 3/3
# 164/164 [==============================] - 166s 1s/step - loss: 0.1427 - accuracy: 0.9431
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 20s 969ms/step - loss: 0.6359 - accuracy: 0.7179
# ********************
# ********************
# learning rate 0.011
# momentum 0.94
# Found 5239 images belonging to 2 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 532, 399, 8)       208
#
#  dropout_8 (Dropout)         (None, 532, 399, 8)       0
#
#  batch_normalization_2 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_9 (Dropout)         (None, 264, 198, 8)       0
#
#  conv2d_12 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_13 (Conv2D)          (None, 42, 31, 16)        6288
#
#  dropout_10 (Dropout)        (None, 42, 31, 16)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 9, 6, 32)          12832
#
#  dropout_11 (Dropout)        (None, 9, 6, 32)          0
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 384)               0
#
#  dense_4 (Dense)             (None, 32)                12320
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 171s 1s/step - loss: 0.5332 - accuracy: 0.7631
# Epoch 2/3
# 164/164 [==============================] - 174s 1s/step - loss: 0.2332 - accuracy: 0.9124
# Epoch 3/3
# 164/164 [==============================] - 171s 1s/step - loss: 0.1501 - accuracy: 0.9475
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 925ms/step - loss: 1.0547 - accuracy: 0.7628
# ********************
# ********************
# learning rate 0.013
# momentum 0.9
# Found 5239 images belonging to 2 classes.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 532, 399, 8)       208
#
#  dropout_12 (Dropout)        (None, 532, 399, 8)       0
#
#  batch_normalization_3 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_13 (Dropout)        (None, 264, 198, 8)       0
#
#  conv2d_17 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_18 (Conv2D)          (None, 42, 31, 16)        6288
#
#  dropout_14 (Dropout)        (None, 42, 31, 16)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 9, 6, 32)          12832
#
#  dropout_15 (Dropout)        (None, 9, 6, 32)          0
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 384)               0
#
#  dense_6 (Dense)             (None, 32)                12320
#
#  dense_7 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 172s 1s/step - loss: 0.3137 - accuracy: 0.8652
# Epoch 2/3
# 164/164 [==============================] - 167s 1s/step - loss: 0.1580 - accuracy: 0.9399
# Epoch 3/3
# 164/164 [==============================] - 169s 1s/step - loss: 0.1280 - accuracy: 0.9546
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 19s 948ms/step - loss: 0.4273 - accuracy: 0.8237
# ********************
# ********************
# learning rate 0.013
# momentum 0.92
# Found 5239 images belonging to 2 classes.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 532, 399, 8)       208
#
#  dropout_16 (Dropout)        (None, 532, 399, 8)       0
#
#  batch_normalization_4 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_21 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_17 (Dropout)        (None, 264, 198, 8)       0
#
#  conv2d_22 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_23 (Conv2D)          (None, 42, 31, 16)        6288
#
#  dropout_18 (Dropout)        (None, 42, 31, 16)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 21, 15, 16)       0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 9, 6, 32)          12832
#
#  dropout_19 (Dropout)        (None, 9, 6, 32)          0
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 3, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 384)               0
#
#  dense_8 (Dense)             (None, 32)                12320
#
#  dense_9 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 172s 1s/step - loss: 0.5924 - accuracy: 0.7389
# Epoch 2/3
# 164/164 [==============================] - 169s 1s/step - loss: 0.5724 - accuracy: 0.7412
# Epoch 3/3
# 164/164 [==============================] - 167s 1s/step - loss: 0.5725 - accuracy: 0.7412
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 18s 886ms/step - loss: 0.7003 - accuracy: 0.6250
# ********************
# ********************
# learning rate 0.013
# momentum 0.94
# Found 5239 images belonging to 2 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 532, 399, 8)       208
#
#  dropout_20 (Dropout)        (None, 532, 399, 8)       0
#
#  batch_normalization_5 (Batc  (None, 532, 399, 8)      32
#  hNormalization)
#
#  conv2d_26 (Conv2D)          (None, 264, 198, 8)       1608
#
#  dropout_21 (Dropout)        (None, 264, 198, 8)       0
#
#  conv2d_27 (Conv2D)          (None, 130, 97, 8)        1608
#
#  conv2d_28 (Conv2D)          (None, 42, 31, 16)        6288
#
#  dropout_22 (Dropout)        (None, 42, 31, 16)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 21, 15, 16)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 9, 6, 32)          12832
#
#  dropout_23 (Dropout)        (None, 9, 6, 32)          0
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 3, 32)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 384)               0
#
#  dense_10 (Dense)            (None, 32)                12320
#
#  dense_11 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 34,962
# Trainable params: 34,946
# Non-trainable params: 16
# _________________________________________________________________
# Epoch 1/3
# 164/164 [==============================] - 172s 1s/step - loss: 0.5374 - accuracy: 0.7622
# Epoch 2/3
# 164/164 [==============================] - 167s 1s/step - loss: 0.2510 - accuracy: 0.8983
# Epoch 3/3
# 164/164 [==============================] - 168s 1s/step - loss: 0.2056 - accuracy: 0.9177
# Found 624 images belonging to 2 classes.
# 20/20 [==============================] - 18s 893ms/step - loss: 0.7916 - accuracy: 0.7260
